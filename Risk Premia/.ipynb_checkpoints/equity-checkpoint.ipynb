# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Purpose of the Notebook
#
# Find the beta loadings of the ETFs per country

# %% [markdown]
# # Fama French

# %%
os.getcwd()
# Out:
# '/home/jupyter/AFP/Risk Premia'

# %%
country_etfs = pd.read_csv('../Data/country_data/ETF_adj_close.csv')

# %%
country_etfs
# Out:
#       Unnamed: 0  Argentina     Brazil      Chile      China  Colombia  \
# 0     1996-03-19        NaN        NaN        NaN        NaN       NaN
# 1     1996-03-20        NaN        NaN        NaN        NaN       NaN
# 2     1996-03-21        NaN        NaN        NaN        NaN       NaN
# 3     1996-03-22        NaN        NaN        NaN        NaN       NaN
# 4     1996-03-25        NaN        NaN        NaN        NaN       NaN
# ...          ...        ...        ...        ...        ...       ...
# 6251  2021-01-19  30.930000  36.680000  31.850000  88.720001     11.38
# 6252  2021-01-20  31.309999  36.660000  32.630001  91.400002     11.43
# 6253  2021-01-21  30.629999  35.980000  32.680000  91.099998     11.33
# 6254  2021-01-22  30.620001  35.040001  31.610001  91.059998     10.93
# 6255  2021-01-25  30.110001  34.520000  31.350000  92.910004     10.57
#
#           Egypt     Greece      India      Korea  ...  Philippines     Poland  \
# ...
